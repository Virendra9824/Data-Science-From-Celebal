# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
p1 = np.array([0,6])
p2 = np.array([0,250])

# %%
plt.plot(p1,p2)

# %%
plt.plot(p1,p2, 'o')

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

# %%
plt.plot(xpoints, ypoints)

# %%
ypoints = np.array([0,2,0,2, 0, 2])

# %%
plt.plot(ypoints, marker='*')

# %% [markdown]
# ### Format Strings fmt

# %% [markdown]
# ##### shortcut string notation --> marker|line|color

# %%
plt.plot(ypoints, 'o-.r', ms=20, mec='b', mfc='hotpink')

# %%
plt.plot(ypoints, 'o-.r', ms=20, mec='b', mfc='hotpink', linewidth='5.5')

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

# %%
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x1 = np.array([0, 6, 2, 3])
y1 = np.array([3, 8, 0, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 9, 10])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title('Demo Plot', fontdict=font1, loc='left')
plt.xlabel("Average Pulse", fontdict=font2)
plt.ylabel("Calorie Burnage", fontdict=font2)

plt.grid()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title('Demo Plot', fontdict=font1, loc='left')
plt.xlabel("Average Pulse", fontdict=font2)
plt.ylabel("Calorie Burnage", fontdict=font2)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])


# plt.scatter(x, y, c=colors, cmap='cool')
plt.scatter(x, y, c=colors, cmap='hot', sizes=sizes)
plt.colorbar()

plt.show()

# %%
x = np.random.randint(100, size=100)
y = np.random.randint(100, size=100)

colors = np.random.randint(100, size=100)
size = 5*np.random.randint(100, size=100)

plt.scatter(x,y, c=colors, sizes=size)
plt.colorbar()
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y, height=0.4, color='hotpink')
plt.show()

# %%
x = np.random.normal(150, 10, 200)
plt.hist(x)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()
